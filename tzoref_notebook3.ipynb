# %% [markdown]
# # Jupyter Notebook for Week 3
#
# * Student Name: Shani Tzoref
# * Date: September 9, 2019
# * Assignment Due: September 10, 2019
# * Instructor: Lisa Rhody
# * Methods of Text Analysis, Fall 2019

# %% [markdown]
# For the following assignment, you will be working through exercises from _Natural Language Processing with Python: Analyzing Text with the Natural Langauge Toolkit_ by Steven Bird, Ewan Klein, and Edward Loper. The book can be found at http://www.nltk.org/book/. It might be helpful to have this window open on 1/2 of your computer monitor and the text of the NLP with Python book open right next to it on the other 1/2 of your screen.
#
# Periodically, throughout the notebook, you will be prompted to add a "markdown" cell and to write a reflection that connects your secondary reading of Miller and McGann with the code that you are running in the Jupyter notebook.
#
# I encourage you to add cells and to create little experiments as you go. If you do, please alert me to them by inserting a markdown cell directly above or below your experiment to explain what you are doing.

# %%
import nltk
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %% [markdown]
# # Searching Text

# %%
text1.concordance("monstrous")
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %% [markdown]
# #ST: **"My Turn":** Insert some additional searches: suggestions from NLTK book and independent

# %%
text1.concordance("God")
text2.concordance("affection")
text2.concordance("monstrous")
text2.concordance("affections")
text3.concordance("lived")
text4.concordance("nation")
text4.concordance("terror")
text4.concordance("god")
text5.concordance("luv")
text5.concordance("bitch")
# Out:
# Displaying 25 of 152 matches:
# linterable glasses ! EXTRACTS . " And God created great whales ." -- GENESIS .
#  . " That sea beast Leviathan , which God of all his works Created hugest that
#  . A . D . 1668 . " Whales in the sea God ' s voice obey ." -- N . E . PRIMER .
#  ' S CONVERSATIONS WITH GOETHE . " My God ! Mr . Chace , what is the matter ?"
# out me in the dark . " Landlord , for God ' s sake , Peter Coffin !" shouted I
#  of the word , to the faithful man of God , this pulpit , I see , is a self - c
# orld . From thence it is the storm of God ' s quick wrath is first descried , a
# arliest brunt . From thence it is the God of breezes fair or foul is first invo
# ed over me a dismal gloom , While all God ' s sun - lit waves rolled by , And l
# r . " In black distress , I called my God , When I could scarce believe him min
# htning shone The face of my Deliverer God . " My song for ever shall record Tha
# ...

# %% [markdown]
# **REFLECTION:** In _The Textual Condition_, McGann writes: "Both the practice and the study of human culture comprise a network of symbolic exchanges. Because human beings are not angels, these exchanges always involve material negotiations." What is the "symbolic exchange" that happens in creating a concordance like the one above? How are these "material negotiations" or not? Consider how this may or may not relate to the use of the method "similar" below.

# %% [markdown]
# #ST **REFLECTION RESPONSE:** When the code is run, the sequence of letters m-o-n-s-t-r-o-u-s inserted in quotation marks and between parentheses following the code function concordance and applied to the text of the book Moby Dick that has been designated text1 is exchanged for a displayed list of all the occurences of those letters in that sequence in that book, according to their appearance in the book, with some preceding and following words to represent the context.  The visible display of the code and result in the Jupyter notebook are material in a conventional sense, in their physicality. I realize that I do not know what software "is", although I would consider the invisible bits and bytes that serve as receptacles for the data to be mediators of materiality.  (I find a similar definition of materiality in terms of "practical instsantiation", in the 2nd category of "materiality" discussed by Paul M. Leonardi, "Digital materiality? How artifacts without matter, matter"https://firstmonday.org/article/view/3036/2567; I think that extending materiality to "significance", as he does in his third category, stretches the definition beyond usefulness).
#
# I continue to see a symbolic exchange, though extended and weaker, in the function "similar".  The letters of the word "monstrous" in the code are still symbols for the occurences of this word in the text Moby Dick, but they are exchanged for the list of lengthier sequences of surrounding words, representing the context. The comparison with the contexts of other words might involve more of a negotiation than was necessary for the simple concordance command. The output display no longer contains the same word as the input, so the material connection is diminished, but there remains a material physical representation of words related to "monstrous".

# %%
text1.similar("monstrous")
# Out:
# true contemptible christian abundant few part mean careful puzzled
# mystifying passing curious loving wise doleful gamesome singular
# delightfully perilous fearless

# %%
text2.common_contexts(["monstrous", "very"])
# Out:
# a_pretty am_glad a_lucky is_pretty be_glad

# %% [markdown]
# #ST: **"My Turn":** pick another pair of words and compare their usage in two different texts, using the similar() and common_contexts() functions.

# %%
text1.similar("comical")
# Out:
# other very strange vain sand easy nameless sweet bland securely peleg
# cleanliest glad foregoing

# %%
text2.similar("comical")
# Out:
# No matches

# %%
text1.similar("fear")
# Out:
# thought am see whales men doubt love do him was all it hand whale more
# english will have said no

# %%
text2.similar("fear")
# Out:
# hope think wish thought believe , one desire promise day kind fancy
# know suppose want style felt hear body sense

# %%
text2.common_contexts(["thought", "sense"])
# Out:
# of_, a_of

# %% [markdown]
# **REFLECTION:** How does your sense of "context" and "symbolic exchange" change (or not) when you view the frequency of a word's use distributed across a novel using a "dispersion plot."?

# %% [markdown]
# #ST **REFLECTION RESPONSE:** I am not sufficiently familiar with dispersion plots to have an strong response to the visual effect of a dispersion plot. I see the graphic mostly as representating tools and methods that will give me new types of access to analysis of texts and contexts, more than as meaningful representation to clustered concurrences of the words "freedom" and "America" in the corpus of inaugural addresses, or the non-matching distribution of "duties" with those terms.
#
# The graphic feels like an "exchange" to me in the sense of substitution, replacement, but it feels more transmissional than interactive.  I see the computational data is a receptacle for some sort of "real meaning" that inheres in the words and texts, and so I see less reciprocity in the relationship between the dispersion plot and the words of the text or their meaning.
#
# The graphic takes the "symbolic" exchange a step away from the verbal and towards abstraction. In one way, this computational abstraction feels further removed from the abstract "original thoughts" of the authors of the addresses; on the other hand, it could give readers greater access to some of the culturally contextual assumptions that birthed those thoughts, with or without the conscious intent of the authors.

# %% [markdown]
# #ST **ANNOTATION**: I am running code on text4 to recall what the text is.

# %%
text4
# Out:
# <Text: Inaugural Address Corpus>

# %%
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America"])

# %% [markdown]
# # 1.4 Counting Vocabulary

# %% [markdown]
# Follow along in http://www.nltk.org/book/ch01.html by reading the description and then running the cells below. What do the authors mean by a "token"? How is a "token" different from "text"?

# %% [markdown]
# #ST **RESPONSE:** The authors explain a "token" as a discrete unit of a sequence of characters that is treated as a group. It seems to be the smallest unit that can be treated as having contextual meaning, and the designation seems to relate to being set off by a space.
#
# The word "text" has too many possible meanings for me to understand how to use it as a comaparandum. In the context of this question, I guess I might say that a "token" can refer to a unit of characters that contains no alphanumeric characters, while I might require a "text" to contain some words. (But then what about emojis?).
#
# Or maybe a difference is length, or hierarchical categories, in that I would see a text as containing "tokens"
#
# So, maybe, the key difference would be that I see tokens as having meaning computationally-- as units of character-sequences within a text, while i see a "text" as having content-meaning, particularly verbal.

# %%
len(text3)
# Out:
# 44764

# %%
sorted(set(text3))
# Out:
# ['!',
#  "'",
#  '(',
#  ')',
#  ',',
#  ',)',
#  '.',
#  '.)',
#  ':',
#  ';',
#  ';)',
#  '?',
#  '?)',
#  'A',
#  'Abel',
#  'Abelmizraim',
#  'Abidah',
#  'Abide',
#  'Abimael',
#  'Abimelech',
#  'Abr',
#  'Abrah',
#  'Abraham',
#  'Abram',
#  'Accad',
#  'Achbor',
#  'Adah',
#  'Adam',
#  'Adbeel',
#  'Admah',
#  'Adullamite',
#  'After',
#  'Aholibamah',
#  'Ahuzzath',
#  'Ajah',
#  'Akan',
#  'All',
#  'Allonbachuth',
#  'Almighty',
#  'Almodad',
#  'Also',
#  'Alvah',
#  'Alvan',
#  'Am',
#  'Amal',
#  'Amalek',
#  'Amalekites',
#  'Ammon',
#  'Amorite',
#  'Amorites',
#  'Amraphel',
#  'An',
#  'Anah',
#  'Anamim',
#  'And',
#  'Aner',
#  'Angel',
#  'Appoint',
#  'Aram',
#  'Aran',
#  'Ararat',
#  'Arbah',
#  'Ard',
#  'Are',
#  'Areli',
#  'Arioch',
#  'Arise',
#  'Arkite',
#  'Arodi',
#  'Arphaxad',
#  'Art',
#  'Arvadite',
#  'As',
#  'Asenath',
#  'Ashbel',
#  'Asher',
#  'Ashkenaz',
#  'Ashteroth',
#  'Ask',
#  'Asshur',
#  'Asshurim',
#  'Assyr',
#  'Assyria',
# ...

# %%
len(set(text3))
# Out:
# 2789

# %% [markdown]
# What is the difference between "word types" and a "types"? How are these meanings distinct from other uses of the word "types" that you are familiar with?

# %% [markdown]
# #ST **RESPONSE:** "Word types" consist of alphabetical (and numerical?) characters, and "types" include punctuation symbols.  I associate "type" with either a broad category, sort, rather than a more specific distinctive designator. Although an association with typography might bridge that gap.
#
# (On "types", I found this sentence helpful, from the Wikipedia article referenced at the end of the chapter in the NLTK book: "There are 26 letter types in the English alphabet and yet there are more than 26 letter occurrences in this sentence type. Moreover, every time a child writes the alphabet 26 new letter tokens have been created." https://en.wikipedia.org/wiki/Type%E2%80%93token_distinction)

# %%
len(set(text3)) / len(text3)
# Out:
# 0.06230453042623537

# %%
text3.count("smote")
# Out:
# 5

# %%
100 * text4.count('a') / len(text4)
# Out:
# 1.457973123627309

# %% [markdown]
# #ST **"My Turn:"** How many times does the word lol appear in text5? How much is this as a percentage of the total number of words in this text?

# %%
text5.count("lol")
# Out:
# 704

# %%
text5.count("lol") / len(set(text5))
# Out:
# 0.11605670952851961

# %%
def lexical_diversity(text):
    return len(set(text)) / len(text)
def percentage(count, total):
    return 100 * count / total

# %%
lexical_diversity(text3)
# Out:
# 0.06230453042623537

# %%
lexical_diversity(text5)
# Out:
# 0.13477005109975562

# %%
percentage(4, 5)
# Out:
# 80.0

# %%
percentage(text4.count('a'), len(text4))
# Out:
# 1.457973123627309

# %% [markdown]
# **REFLECTION:** McGann writes on page 4 that "Today, texts are largely imagined as scenes of reading rather than scenes of writing. This 'readerly' view of text has been most completely elaborated through the modern hermeneutical tradition in which text is not something we _make_ but something we _interpret_." How does McGann's view of the text relate to the "reading" that happens in this notebook? Consider his later question: "Where--and how--does the activity of reading take place?"
#
# 3ST **REFLECTION RESPONSE:** In this notebook, the NLTK book is being read by you, Lisa --(the 2nd person form is odd here; are you my implied reader?  or is your role an observer and evaluator of my address to another, fictive, potential, imagined reader?) -- in such a way as to generate textual production, in the creation of questions and eliciting of responses. It is like an adaptation of McGann's description of the autopoiesis of poetry, brought to the world of information; informing through interaction, transaction, and production rather than unidirectional transmission alone.  I would still say that I am interpreting the NLTK book, and the assignment questions--attempting to discern the messages and instructions of the authors, but I am also interacting with the texts, utilizing the openings they've created, acting on their explicit and implicit invitations.

# %% [markdown]
# # Chapter 2 Accessing Text Corpora and Lexical Resources

# %% [markdown]
# Ok, now we're going to shift a bit and look at Chapter 2 of the NLP book http://www.nltk.org/book/ch02.html. (Don't worry, we'll come back to the rest of Chapter 1 next week.) McGann talks about different _types_ of text in his introduction: "Even the most 'informational' text comprises an interactive mechanism of communicative exchange." We're going to look at different texts in the NLTK corpus. Again, the easiest way to proceed here is to open Chapter 2 in a window on one side of your monitor and this notebook in the other and to read simultaneously.

# %%
# remember, we already ran import nltk earlier in the notebook
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
emma = nltk.corpus.gutenberg.words('austen-emma.txt')
len(emma)
# Out:
# 192427

# %%
emma = nltk.Text(nltk.corpus.gutenberg.words('austen-emma.txt'))
emma.concordance("surprize")
# Out:
# Displaying 25 of 37 matches:
# er father , was sometimes taken by surprize at his being still able to pity `
# hem do the other any good ." " You surprize me ! Emma must do Harriet good : a
# Knightley actually looked red with surprize and displeasure , as he stood up ,
# r . Elton , and found to his great surprize , that Mr . Elton was actually on
# d aid ." Emma saw Mrs . Weston ' s surprize , and felt that it must be great ,
# father was quite taken up with the surprize of so sudden a journey , and his f
# y , in all the favouring warmth of surprize and conjecture . She was , moreove
# he appeared , to have her share of surprize , introduction , and pleasure . Th
# ir plans ; and it was an agreeable surprize to her , therefore , to perceive t
# talking aunt had taken me quite by surprize , it must have been the death of m
# f all the dialogue which ensued of surprize , and inquiry , and congratulation
# ...

# %%
from nltk.corpus import gutenberg
gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
emma = gutenberg.words('austen-emma.txt')

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/shanitzoref/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
for fileid in gutenberg.fileids():
    num_chars = len(gutenberg.raw(fileid))
    num_words = len(gutenberg.words(fileid))
    num_sents = len(gutenberg.sents(fileid))
    num_vocab = len(set(w.lower() for w in gutenberg.words(fileid)))
    print(round(num_chars/num_words), round(num_words/num_sents), round(num_words/num_vocab), fileid)
# Out:
# 5 25 26 austen-emma.txt
# 5 26 17 austen-persuasion.txt
# 5 28 22 austen-sense.txt
# 4 34 79 bible-kjv.txt
# 5 19 5 blake-poems.txt
# 4 19 14 bryant-stories.txt
# 4 18 12 burgess-busterbrown.txt
# 4 20 13 carroll-alice.txt
# 5 20 12 chesterton-ball.txt
# 5 23 11 chesterton-brown.txt
# 5 18 11 chesterton-thursday.txt
# 4 21 25 edgeworth-parents.txt
# 5 26 15 melville-moby_dick.txt
# 5 52 11 milton-paradise.txt
# 4 12 9 shakespeare-caesar.txt
# 4 12 8 shakespeare-hamlet.txt
# 4 12 7 shakespeare-macbeth.txt
# 5 36 12 whitman-leaves.txt

# %%
macbeth_sentences = gutenberg.sents('shakespeare-macbeth.txt')
macbeth_sentences
# Out:
# [['[', 'The', 'Tragedie', 'of', 'Macbeth', 'by', 'William', 'Shakespeare', '1603', ']'], ['Actus', 'Primus', '.'], ...]

# %% [markdown]
# # 1.2 Web and Chat Text

# %%
from nltk.corpus import webtext
for fileid in webtext.fileids():
    print(fileid, webtext.raw(fileid)[:65], '...')
# Out:
# firefox.txt Cookie Manager: "Don't allow sites that set removed cookies to se ...
# grail.txt SCENE 1: [wind] [clop clop clop]
# KING ARTHUR: Whoa there!  [clop ...
# overheard.txt White guy: So, do you have any plans for this evening?
# Asian girl ...
# pirates.txt PIRATES OF THE CARRIBEAN: DEAD MAN'S CHEST, by Ted Elliott & Terr ...
# singles.txt 25 SEXY MALE, seeks attrac older single lady, for discreet encoun ...
# wine.txt Lovely delicate, fragrant Rhone wine. Polished leather and strawb ...

# %%
from nltk.corpus import nps_chat
chatroom = nps_chat.posts('10-19-20s_706posts.xml')
chatroom[123]
# Out:
# ['i',
#  'do',
#  "n't",
#  'want',
#  'hot',
#  'pics',
#  'of',
#  'a',
#  'female',
#  ',',
#  'I',
#  'can',
#  'look',
#  'in',
#  'a',
#  'mirror',
#  '.']

# %%
from nltk.corpus import brown
brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %% [markdown]
# # 1.3 Brown Corpus

# %%
from nltk.corpus import brown
news_text = brown.words(categories='news')
fdist = nltk.FreqDist(w.lower() for w in news_text)
modals = ['can','could','may','might','must','will']
for m in modals:
    print(m + ":", fdist[m], end=" ")
# Out:
# can: 94 could: 87 may: 93 might: 38 must: 53 will: 389

# %%
brown.sents(categories=['news','editorial','reviews'])
# Out:
# [['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'an', 'investigation', 'of', "Atlanta's", 'recent', 'primary', 'election', 'produced', '``', 'no', 'evidence', "''", 'that', 'any', 'irregularities', 'took', 'place', '.'], ['The', 'jury', 'further', 'said', 'in', 'term-end', 'presentments', 'that', 'the', 'City', 'Executive', 'Committee', ',', 'which', 'had', 'over-all', 'charge', 'of', 'the', 'election', ',', '``', 'deserves', 'the', 'praise', 'and', 'thanks', 'of', 'the', 'City', 'of', 'Atlanta', "''", 'for', 'the', 'manner', 'in', 'which', 'the', 'election', 'was', 'conducted', '.'], ...]

# %%
cfd = nltk.ConditionalFreqDist(
        (genre,word)
        for genre in brown.categories()
        for word in brown.words(categories=genre))
genres = ['news', 'relgion', 'hobbies', 'science_fiction', 'romance', 'humor']
modals = ['can', 'could', 'may', 'might', 'must', 'will']
cfd.tabulate(conditions=genres, samples=modals)
# Out:
#                   can could   may might  must  will
#            news    93    86    66    38    50   389
#         relgion     0     0     0     0     0     0
#         hobbies   268    58   131    22    83   264
# science_fiction    16    49     4    12     8    16
#         romance    74   193    11    51    45    43
#           humor    16    30     8     8     9    13

# %%
from nltk.corpus import inaugural
inaugural.fileids()
# Out:
# ['1789-Washington.txt',
#  '1793-Washington.txt',
#  '1797-Adams.txt',
#  '1801-Jefferson.txt',
#  '1805-Jefferson.txt',
#  '1809-Madison.txt',
#  '1813-Madison.txt',
#  '1817-Monroe.txt',
#  '1821-Monroe.txt',
#  '1825-Adams.txt',
#  '1829-Jackson.txt',
#  '1833-Jackson.txt',
#  '1837-VanBuren.txt',
#  '1841-Harrison.txt',
#  '1845-Polk.txt',
#  '1849-Taylor.txt',
#  '1853-Pierce.txt',
#  '1857-Buchanan.txt',
#  '1861-Lincoln.txt',
#  '1865-Lincoln.txt',
#  '1869-Grant.txt',
#  '1873-Grant.txt',
#  '1877-Hayes.txt',
#  '1881-Garfield.txt',
#  '1885-Cleveland.txt',
#  '1889-Harrison.txt',
#  '1893-Cleveland.txt',
#  '1897-McKinley.txt',
#  '1901-McKinley.txt',
#  '1905-Roosevelt.txt',
#  '1909-Taft.txt',
#  '1913-Wilson.txt',
#  '1917-Wilson.txt',
#  '1921-Harding.txt',
#  '1925-Coolidge.txt',
#  '1929-Hoover.txt',
#  '1933-Roosevelt.txt',
#  '1937-Roosevelt.txt',
#  '1941-Roosevelt.txt',
#  '1945-Roosevelt.txt',
#  '1949-Truman.txt',
#  '1953-Eisenhower.txt',
# ...

# %%
from nltk.corpus import reuters
reuters.fileids()
# Out:
# ['test/14826',
#  'test/14828',
#  'test/14829',
#  'test/14832',
#  'test/14833',
#  'test/14839',
#  'test/14840',
#  'test/14841',
#  'test/14842',
#  'test/14843',
#  'test/14844',
#  'test/14849',
#  'test/14852',
#  'test/14854',
#  'test/14858',
#  'test/14859',
#  'test/14860',
#  'test/14861',
#  'test/14862',
#  'test/14863',
#  'test/14865',
#  'test/14867',
#  'test/14872',
#  'test/14873',
#  'test/14875',
#  'test/14876',
#  'test/14877',
#  'test/14881',
#  'test/14882',
#  'test/14885',
#  'test/14886',
#  'test/14888',
#  'test/14890',
#  'test/14891',
#  'test/14892',
#  'test/14899',
#  'test/14900',
#  'test/14903',
#  'test/14904',
#  'test/14907',
#  'test/14909',
#  'test/14911',
#  'test/14912',
#  'test/14913',
#  'test/14918',
#  'test/14919',
#  'test/14921',
#  'test/14922',
#  'test/14923',
#  'test/14926',
#  'test/14928',
#  'test/14930',
#  'test/14931',
#  'test/14932',
#  'test/14933',
#  'test/14934',
#  'test/14941',
#  'test/14943',
# ...

# %%
reuters.categories()
# Out:
# ['acq',
#  'alum',
#  'barley',
#  'bop',
#  'carcass',
#  'castor-oil',
#  'cocoa',
#  'coconut',
#  'coconut-oil',
#  'coffee',
#  'copper',
#  'copra-cake',
#  'corn',
#  'cotton',
#  'cotton-oil',
#  'cpi',
#  'cpu',
#  'crude',
#  'dfl',
#  'dlr',
#  'dmk',
#  'earn',
#  'fuel',
#  'gas',
#  'gnp',
#  'gold',
#  'grain',
#  'groundnut',
#  'groundnut-oil',
#  'heat',
#  'hog',
#  'housing',
#  'income',
#  'instal-debt',
#  'interest',
#  'ipi',
#  'iron-steel',
#  'jet',
#  'jobs',
#  'l-cattle',
#  'lead',
#  'lei',
#  'lin-oil',
#  'livestock',
#  'lumber',
#  'meal-feed',
#  'money-fx',
#  'money-supply',
#  'naphtha',
#  'nat-gas',
#  'nickel',
#  'nkr',
#  'nzdlr',
#  'oat',
#  'oilseed',
#  'orange',
#  'palladium',
#  'palm-oil',
#  'palmkernel',
#  'pet-chem',
#  'platinum',
#  'potato',
#  'propane',
#  'rand',
#  'rape-oil',
#  'rapeseed',
#  'reserves',
#  'retail',
#  'rice',
#  'rubber',
#  'rye',
#  'ship',
#  'silver',
#  'sorghum',
#  'soy-meal',
#  'soy-oil',
# ...

# %% [markdown]
# You can skip the remainder of the Reuters section. We'll return to this later.

# %% [markdown]
# # 1.5 Inaugural Address Corpus

# %%
from nltk.corpus import inaugural
inaugural.fileids()
# Out:
# ['1789-Washington.txt',
#  '1793-Washington.txt',
#  '1797-Adams.txt',
#  '1801-Jefferson.txt',
#  '1805-Jefferson.txt',
#  '1809-Madison.txt',
#  '1813-Madison.txt',
#  '1817-Monroe.txt',
#  '1821-Monroe.txt',
#  '1825-Adams.txt',
#  '1829-Jackson.txt',
#  '1833-Jackson.txt',
#  '1837-VanBuren.txt',
#  '1841-Harrison.txt',
#  '1845-Polk.txt',
#  '1849-Taylor.txt',
#  '1853-Pierce.txt',
#  '1857-Buchanan.txt',
#  '1861-Lincoln.txt',
#  '1865-Lincoln.txt',
#  '1869-Grant.txt',
#  '1873-Grant.txt',
#  '1877-Hayes.txt',
#  '1881-Garfield.txt',
#  '1885-Cleveland.txt',
#  '1889-Harrison.txt',
#  '1893-Cleveland.txt',
#  '1897-McKinley.txt',
#  '1901-McKinley.txt',
#  '1905-Roosevelt.txt',
#  '1909-Taft.txt',
#  '1913-Wilson.txt',
#  '1917-Wilson.txt',
#  '1921-Harding.txt',
#  '1925-Coolidge.txt',
#  '1929-Hoover.txt',
#  '1933-Roosevelt.txt',
#  '1937-Roosevelt.txt',
#  '1941-Roosevelt.txt',
#  '1945-Roosevelt.txt',
#  '1949-Truman.txt',
#  '1953-Eisenhower.txt',
# ...

# %%
cfd = nltk.ConditionalFreqDist(
        (target, fileid[:4])
        for fileid in inaugural.fileids()
        for w in inaugural.words(fileid)
        for target in ['america', 'citizen']
        if w.lower().startswith(target))
cfd.plot()

# %% [markdown]
# # 1.6 Annotated Text Corpora

# %% [markdown]
# We will return to annotated text corpora later. You can choose to run the cells in this section if you wish. If you prefer to skip ahead, that is fine, too. However, consider in this section of the assignment the challenges that language differences present to text analysis.

# %%
nltk.corpus.cess_esp.words()
# Out:
# ['Guillermo_de_la_Torre', ',', 'entrenador', 'del', ...]

# %% [markdown]
# #ST **PROBLEM/QUESTION?:** When I tried to run the code in the cell below, I received an error message:
#
# ValueError: concat() expects at least one object

# %%
nltk.corpus.floresta.words()
# Out:
# ['Um', 'revivalismo', 'refrescante', 'O', '7_e_Meio', ...]

# %%
nltk.corpus.indian.words('hindi.pos')
# Out:
# ['पूर्ण', 'प्रतिबंध', 'हटाओ', ':', 'इराक', 'संयुक्त', ...]

# %%
nltk.corpus.udhr.fileids()
# Out:
# ['Abkhaz-Cyrillic+Abkh',
#  'Abkhaz-UTF8',
#  'Achehnese-Latin1',
#  'Achuar-Shiwiar-Latin1',
#  'Adja-UTF8',
#  'Afaan_Oromo_Oromiffa-Latin1',
#  'Afrikaans-Latin1',
#  'Aguaruna-Latin1',
#  'Akuapem_Twi-UTF8',
#  'Albanian_Shqip-Latin1',
#  'Amahuaca',
#  'Amahuaca-Latin1',
#  'Amarakaeri-Latin1',
#  'Amuesha-Yanesha-UTF8',
#  'Arabela-Latin1',
#  'Arabic_Alarabia-Arabic',
#  'Asante-UTF8',
#  'Ashaninca-Latin1',
#  'Asheninca-Latin1',
#  'Asturian_Bable-Latin1',
#  'Aymara-Latin1',
#  'Balinese-Latin1',
#  'Bambara-UTF8',
#  'Baoule-UTF8',
#  'Basque_Euskara-Latin1',
#  'Batonu_Bariba-UTF8',
#  'Belorus_Belaruski-Cyrillic',
#  'Belorus_Belaruski-UTF8',
#  'Bemba-Latin1',
#  'Bengali-UTF8',
#  'Beti-UTF8',
#  'Bichelamar-Latin1',
#  'Bikol_Bicolano-Latin1',
#  'Bora-Latin1',
#  'Bosnian_Bosanski-Cyrillic',
#  'Bosnian_Bosanski-Latin2',
#  'Bosnian_Bosanski-UTF8',
#  'Breton-Latin1',
#  'Bugisnese-Latin1',
#  'Bulgarian_Balgarski-Cyrillic',
#  'Bulgarian_Balgarski-UTF8',
# ...

# %%
nltk.corpus.udhr.words('Javanese-Latin1')[11:]
# Out:
# ['Saben', 'umat', 'manungsa', 'lair', 'kanthi', 'hak', ...]

# %%
from nltk.corpus import udhr
languages = ['Chickasaw', 'English', 'German_Deutsch',
             'Greenlandic_Inuktikut', 'Hungarian_Magyar', 'Ibibio_Efik']
cfd = nltk.ConditionalFreqDist(
          (lang, len(word))
          for lang in languages
          for word in udhr.words(lang + '-Latin1'))
cfd.plot(cumulative=True)

# %%
help(nltk.corpus.reader)
# Out:
# Help on package nltk.corpus.reader in nltk.corpus:
#
# NAME
#     nltk.corpus.reader
#
# DESCRIPTION
#     NLTK corpus readers.  The modules in this package provide functions
#     that can be used to read corpus fileids in a variety of formats.  These
#     functions can be used to read both the corpus fileids that are
#     distributed in the NLTK corpus package, and corpus fileids that are part
#     of external corpora.
#
#     Corpus Reader Functions
# ...
#     Each corpus module defines one or more "corpus reader functions",
#     which can be used to read documents from that corpus.  These functions
#     take an argument, ``item``, which is used to indicate which document
#     should be read from the corpus:
#
#     - If ``item`` is one of the unique identifiers listed in the corpus
#       module's ``items`` variable, then the corresponding document will
#       be loaded from the NLTK corpus package.
#     - If ``item`` is a fileid, then that file will be read.
#
# ...

# %%
raw = gutenberg.raw("burgess-busterbrown.txt")
raw[1:20]
# Out:
# 'The Adventures of B'

# %%
words = gutenberg.words("burgess-busterbrown.txt")
words[1:20]
# Out:
# ['The',
#  'Adventures',
#  'of',
#  'Buster',
#  'Bear',
#  'by',
#  'Thornton',
#  'W',
#  '.',
#  'Burgess',
#  '1920',
#  ']',
#  'I',
#  'BUSTER',
#  'BEAR',
#  'GOES',
#  'FISHING',
#  'Buster',
#  'Bear']

# %%
sents = gutenberg.sents("burgess-busterbrown.txt")
sents[1:20]
# Out:
# [['I'],
#  ['BUSTER', 'BEAR', 'GOES', 'FISHING'],
#  ['Buster',
#   'Bear',
#   'yawned',
#   'as',
#   'he',
#   'lay',
#   'on',
#   'his',
#   'comfortable',
#   'bed',
#   'of',
#   'leaves',
#   'and',
#   'watched',
#   'the',
#   'first',
#   'early',
#   'morning',
#   'sunbeams',
#   'creeping',
#   'through',
#   'the',
#   'Green',
#   'Forest',
#   'to',
#   'chase',
#   'out',
#   'the',
#   'Black',
#   'Shadows',
#   '.'],
#  ['Once',
#   'more',
#   'he',
#   'yawned',
#   ',',
#   'and',
#   'slowly',
#   'got',
#   'to',
#   'his',
#   'feet',
#   'and',
#   'shook',
#   'himself',
#   '.'],
#  ['Then',
#   'he',
#   'walked',
#   'over',
#   'to',
#   'a',
#   'big',
#   'pine',
#   '-',
#   'tree',
#   ',',
#   'stood',
#   'up',
#   'on',
#   'his',
#   'hind',
#   'legs',
#   ',',
#   'reached',
#   'as',
#   'high',
#   'up',
#   'on',
#   'the',
#   'trunk',
#   'of',
#   'the',
#   'tree',
#   'as',
#   'he',
#   'could',
#   ',',
#   'and',
#   'scratched',
# ...

# %%
from nltk.corpus import PlaintextCorpusReader

# %%
corpus_root = '/usr/share/dict'

# %%
wordlists = PlaintextCorpusReader(corpus_root, '.*')

# %%
wordlists.fileids()
# Out:
# ['README', 'connectives', 'propernames', 'web2', 'web2a', 'words']

# %%
wordlists.words('connectives')
# Out:
# ['the', 'of', 'and', 'to', 'a', 'in', 'that', 'is', ...]

# %%
from urllib.request import urlopen
my_url = "https://www.gutenberg.org/files/32/32-0.txt"
file = urlopen(my_url)
raw = file.read()
herland = raw.decode()

# %%
len(herland)
# Out:
# 322692

# %%
her_tokens = nltk.word_tokenize(herland)

# %%
len(her_tokens)
# Out:
# 68494

# %%
herland.concordance("man")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-122-382746f82a3c> in <module>
# ----> 1 herland.concordance("man")
#
# AttributeError: 'str' object has no attribute 'concordance'

# %% [markdown]
# #ST **ANNOTATION.** Attempt to use concordance feature on her_tokens

# %%
her_tokens.concordance("man")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-132-cf57d6930d4d> in <module>
# ----> 1 her_tokens.concordance("man")
#
# AttributeError: 'list' object has no attribute 'concordance'

# %% [markdown]
# Why do you think the statement above threw an error?
#
# #ST **RESPONSE:** Because "herland" is defined as raw text, "not split into tokens".  I would think that since it is not tokenized, the concordance feature, which works with tokens, cannot be applied to it. I cannot use concordance on her_tokens either, since it is a list, rather than a text.
# #ST **QUERY:** If herland is not tokenized, then why is it properly formatted? Maybe I am not clear on the meaning of "tokens"?

# %%
print(herland)
# Out:
# ﻿The Project Gutenberg EBook of Herland, by Charlotte Perkins Stetson Gilman
#
# This eBook is for the use of anyone anywhere at no cost and with
# almost no restrictions whatsoever.  You may copy it, give it away or
# re-use it under the terms of the Project Gutenberg License included
# with this eBook or online at www.gutenberg.org
#
#
# Title: Herland
#
# Author: Charlotte Perkins Stetson Gilman
#
# Posting Date: June 25, 2008 [EBook #32]
# Release Date: May 10, 1992
# Last Updated: October 14, 2016
#
# Language: English
#
# Character set encoding: UTF-8
#
# *** START OF THIS PROJECT GUTENBERG EBOOK HERLAND ***
#
#
#
#
#
#
#
#
#
#
# HERLAND
#
# by Charlotte Perkins Stetson Gilman
#
#
#
#
# CHAPTER 1. A Not Unnatural Enterprise
#
#
# This is written from memory, unfortunately. If I could have brought with
# me the material I so carefully prepared, this would be a very different
# story. Whole books full of notes, carefully copied records, firsthand
# ...

# %% [markdown]
# **REFLECTION**: In _The Textual Condition_ McGann discusses the difference between "text" and "paratext." In the printed version of Herland (above), what would be considered "paratext"?

# %% [markdown]
# #ST **RESPONSE:** The beginning and ending sections:
#
# From "The Project Gutenberg EBook of Herland, by Charlotte Perkins Stetson Gilman" to "* * * START OF THIS PROJECT GUTENBERG EBOOK HERLAND * * *" <nb: i placed spaces between the asterisks to avoid bolding the text, and retain the triple asterisks in the original text>
#
# and then from "End of Project Gutenberg’s Herland, by Charlotte Perkins Stetson Gilman" through the 3 sections including section 1, license and use information; section 2, about the mission of Project Gutenberg; section 3,
# about the Project Gutenberg Literary Archive Foundation; Section 4 about donations to the project; and section 5, General Information about Project Gutenberg electronic works, including the website link.
#
# In the context of considering the Gutenberg ebook, I would not find it helpful to consider the title, author's name, or chapter headings as paratexts, since I see these as intrinsic to the work itself.  (Strictly following Barthes, I suppose I ought to say "the Text" of Herland, since the ebook has created a new edition/work. But I have a different, I hope valid, understanding of "work" and "text" which I hope to flesh out in my blog post for this week).

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
print(word_tokenize(herland))
# Out:
# ['\ufeffThe', 'Project', 'Gutenberg', 'EBook', 'of', 'Herland', ',', 'by', 'Charlotte', 'Perkins', 'Stetson', 'Gilman', 'This', 'eBook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restrictions', 'whatsoever', '.', 'You', 'may', 'copy', 'it', ',', 'give', 'it', 'away', 'or', 're-use', 'it', 'under', 'the', 'terms', 'of', 'the', 'Project', 'Gutenberg', 'License', 'included', 'with', 'this', 'eBook', 'or', 'online', 'at', 'www.gutenberg.org', 'Title', ':', 'Herland', 'Author', ':', 'Charlotte', 'Perkins', 'Stetson', 'Gilman', 'Posting', 'Date', ':', 'June', '25', ',', '2008', '[', 'EBook', '#', '32', ']', 'Release', 'Date', ':', 'May', '10', ',', '1992', 'Last', 'Updated', ':', 'October', '14', ',', '2016', 'Language', ':', 'English', 'Character', 'set', 'encoding', ':', 'UTF-8', '***', 'START', 'OF', 'THIS', 'PROJECT', 'GUTENBERG', 'EBOOK', 'HERLAND', '***', 'HERLAND', 'by', 'Charlotte', 'Perkins', 'Stetson', 'Gilman', 'CH
# ...

# %%
print(sent_tokenize(herland))
# Out:
# ['\ufeffThe Project Gutenberg EBook of Herland, by Charlotte Perkins Stetson Gilman\r\n\r\nThis eBook is for the use of anyone anywhere at no cost and with\r\nalmost no restrictions whatsoever.', 'You may copy it, give it away or\r\nre-use it under the terms of the Project Gutenberg License included\r\nwith this eBook or online at www.gutenberg.org\r\n\r\n\r\nTitle: Herland\r\n\r\nAuthor: Charlotte Perkins Stetson Gilman\r\n\r\nPosting Date: June 25, 2008 [EBook #32]\r\nRelease Date: May 10, 1992\r\nLast Updated: October 14, 2016\r\n\r\nLanguage: English\r\n\r\nCharacter set encoding: UTF-8\r\n\r\n*** START OF THIS PROJECT GUTENBERG EBOOK HERLAND ***\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nHERLAND\r\n\r\nby Charlotte Perkins Stetson Gilman\r\n\r\n\r\n\r\n\r\nCHAPTER 1.', 'A Not Unnatural Enterprise\r\n\r\n\r\nThis is written from memory, unfortunately.', 'If I could have brought with\r\nme the material I so carefully prepared, this would be a very different\r\nstory.', 'Whole book
# ...

# %%
phrases = sent_tokenize(herland)

# %%
words = word_tokenize(herland)

# %%
print(phrases)
# Out:
# ['\ufeffThe Project Gutenberg EBook of Herland, by Charlotte Perkins Stetson Gilman\r\n\r\nThis eBook is for the use of anyone anywhere at no cost and with\r\nalmost no restrictions whatsoever.', 'You may copy it, give it away or\r\nre-use it under the terms of the Project Gutenberg License included\r\nwith this eBook or online at www.gutenberg.org\r\n\r\n\r\nTitle: Herland\r\n\r\nAuthor: Charlotte Perkins Stetson Gilman\r\n\r\nPosting Date: June 25, 2008 [EBook #32]\r\nRelease Date: May 10, 1992\r\nLast Updated: October 14, 2016\r\n\r\nLanguage: English\r\n\r\nCharacter set encoding: UTF-8\r\n\r\n*** START OF THIS PROJECT GUTENBERG EBOOK HERLAND ***\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nHERLAND\r\n\r\nby Charlotte Perkins Stetson Gilman\r\n\r\n\r\n\r\n\r\nCHAPTER 1.', 'A Not Unnatural Enterprise\r\n\r\n\r\nThis is written from memory, unfortunately.', 'If I could have brought with\r\nme the material I so carefully prepared, this would be a very different\r\nstory.', 'Whole book
# ...

# %%
print(words)
# Out:
# ['\ufeffThe', 'Project', 'Gutenberg', 'EBook', 'of', 'Herland', ',', 'by', 'Charlotte', 'Perkins', 'Stetson', 'Gilman', 'This', 'eBook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restrictions', 'whatsoever', '.', 'You', 'may', 'copy', 'it', ',', 'give', 'it', 'away', 'or', 're-use', 'it', 'under', 'the', 'terms', 'of', 'the', 'Project', 'Gutenberg', 'License', 'included', 'with', 'this', 'eBook', 'or', 'online', 'at', 'www.gutenberg.org', 'Title', ':', 'Herland', 'Author', ':', 'Charlotte', 'Perkins', 'Stetson', 'Gilman', 'Posting', 'Date', ':', 'June', '25', ',', '2008', '[', 'EBook', '#', '32', ']', 'Release', 'Date', ':', 'May', '10', ',', '1992', 'Last', 'Updated', ':', 'October', '14', ',', '2016', 'Language', ':', 'English', 'Character', 'set', 'encoding', ':', 'UTF-8', '***', 'START', 'OF', 'THIS', 'PROJECT', 'GUTENBERG', 'EBOOK', 'HERLAND', '***', 'HERLAND', 'by', 'Charlotte', 'Perkins', 'Stetson', 'Gilman', 'CH
# ...

# %% [markdown]
# **Reflection**: How does the definition of _text_ employed by McGann differ from the definition of _text_ employed by the Natural Language Processing book? What similar assumptions might be made about what a text is?

# %% [markdown]
# #ST **REFLECTION RESPONSE:** The NLTP book defines "text" as "raw data for the programs we write", but also employs the word to denote designated collections of such textual data, such as text1, Moby Dick, or text4, the collection of inaugural addresses, and other even more loosely related compilations of texts.  For McGann, the material physicality of a "text" is essential to its existence.  Both NLTP and McGann deal primarily with linguistic entities, and specifically words that are, or can be, represented in graphic form. And both understand text as an inscribed form of communication
